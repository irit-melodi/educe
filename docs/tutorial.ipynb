# %% [markdown]
# Educe
# ======
#
# Installation
# -------------
#
# ```shell
# git clone git@github.com:kowey/educe.git
# cd educe
# sudo pip install -r requirements.txt .
# ```

# %% [markdown]
# Data setup
# -----------

# %%
data_dir = '../data'

# %%
import educe.rst_dt
# read and load the documents from the WSJ which were double-tagged
rst_reader = educe.rst_dt.Reader('{dd}/rst_discourse_treebank/data/RSTtrees-WSJ-double-1.0/'.format(dd=data_dir))
rst_corpus = rst_reader.slurp(verbose=True)
# get the first annotated document
doc0 = rst_corpus[rst_corpus.keys()[0]]
# print the corresponding text
print doc0.text()
# Out:
# Slurping corpus dir [6/53]
# Slurping corpus dir [11/53]
# Slurping corpus dir [15/53]
# Slurping corpus dir [17/53]
# Slurping corpus dir [22/53]
# Slurping corpus dir [26/53]
# Slurping corpus dir [31/53]
# Slurping corpus dir [36/53]
# Slurping corpus dir [41/53]
# Slurping corpus dir [44/53]
# Slurping corpus dir [46/53]
# Slurping corpus dir [51/53]
# Kaufman & Broad Home Corp. said it formed a $53.4 million limited partnership subsidiary to buy land in California suitable for residential development.
#
# The partnership, Kaufman & Broad Land Development Venture Limited Partnership, is a 50-50 joint venture with a trust created by institutional clients of Heitman Advisory Corp., a unit of Heitman Financial Corp., a real estate advisory, management and development company with offices in Chicago and Beverly Hills, Calif.
# Kaufman & Broad, a home building company, declined to identify the institutional investors.
#
# The land to be purchased by the joint venture hasn't yet received zoning and other approvals required for development, and part of Kaufman & Broad's job will be to obtain such approvals.
#
# The partnership runs the risk that it may not get the approvals for development, but in return, it can buy land at wholesale rather than retail prices, which can result in sizable savings, said Bruce Karatz, president and chief executive officer of Kaufman & Broad.
#
# "There are really very few companies that have adequate capital to buy properties in a raw state for cash.
# Typically, developers option property, and then once they get the administrative approvals, they buy it," said Mr. Karatz, adding that he believes the joint venture is the first of its kind. "We usually operate in that conservative manner."
#
# By setting up the joint venture, Kaufman & Broad can take the more aggressive approach of buying raw land, while avoiding the negative impacts to its own balance sheet, Mr. Karatz said.
# The company is putting up only 10% of the capital, although it is responsible for providing management, planning and processing services to the joint venture.
#
# "This is one of the best ways to assure a pipeline of land to fuel our growth at a minimum risk to our company," Mr. Karatz said.
# Slurping corpus dir [53/53 done]

# %% [markdown]
# * RST discourse treebank

# %% [markdown]
# Note for Mac users: if displaying the tree does not work (you should see an embedded PNG file), and you see a GS prompt in your iPython terminal window, try my [NLTK patch](https://github.com/kowey/nltk/commit/4ac4beacff7f9363c84e5d72719e2b5cda8267f2).

# %%
# display PNG tree
from IPython.display import display
display(doc0) # NLTK > 3.0b1 2013-07-11 should display a PNG image of the RST tree
# see note for Mac users
# Out:
# (Root 1-39 ---
#   (Nucleus 1-16 span
#     (Nucleus 1-6 span
#       (Nucleus 1-3 span
#         (Satellite 1-1 attribution EDU:[Kaufman & Broad Home...])
#         (Nucleus 2-3 span
#           (Nucleus 2-2 span EDU:[it formed a $53.4 mi...])
#           (Satellite 3-3 purpose EDU:[to buy land in Calif...])))
#       (Satellite 4-6 elaboration-additional
#         (Nucleus 4-5 span
#           (Nucleus 4-4 span EDU:[The partnership, Kau...])
#           (Satellite 5-5 elaboration-object-attribute-e
#             EDU:[created by instituti...]))
#         (Satellite 6-6 elaboration-additional
#           EDU:[Kaufman & Broad, a h...])))
#     (Satellite 7-16 elaboration-additional
#       (Nucleus 7-11 span
#         (Nucleus 7-10 span
#           (Nucleus 7-8 Same-Unit
#             (Nucleus 7-7 span EDU:[The land])
#             (Satellite 8-8 elaboration-object-attribute-e
#               EDU:[to be purchased by t...]))
#           (Nucleus 9-10 Same-Unit
#             (Nucleus 9-9 span EDU:[hasn't yet received ...])
#             (Satellite 10-10 elaboration-object-attribute-e
#               EDU:[required for develop...])))
#         (Satellite 11-11 elaboration-additional
#           EDU:[and part of Kaufman ...]))
#       (Satellite 12-16 elaboration-additional
#         (Nucleus 12-15 span
#           (Satellite 12-13 concession
#             (Nucleus 12-12 span EDU:[The partnership runs...])
#             (Satellite 13-13 elaboration-object-attribute-e
#               EDU:[that it may not get ...]))
#           (Nucleus 14-15 span
#             (Satellite 14-14 consequence-n
#               EDU:[but in return, it ca...])
#             (Nucleus 15-15 span EDU:[which can result in ...])))
#         (Satellite 16-16 attribution EDU:[said Bruce Karatz, p...]))))
#   (Satellite 17-39 elaboration-additional
#     (Nucleus 17-35 span
#       (Nucleus 17-33 span
#         (Satellite 17-28 background
#           (Nucleus 17-27 span
#             (Satellite 17-19 circumstance
#               (Nucleus 17-17 span EDU:["There are really ve...])
#               (Satellite 18-19 elaboration-object-attribute-e
#                 (Nucleus 18-18 span EDU:[that have adequate c...])
#                 (Satellite 19-19 purpose
#                   EDU:[to buy properties in...])))
#             (Nucleus 20-27 span
#               (Nucleus 20-23 span
#                 (Nucleus 20-20 Sequence
#                   EDU:[Typically, developer...])
#                 (Nucleus 21-23 Sequence
#                   (Nucleus 21-21 Same-Unit EDU:[and then])
#                   (Nucleus 22-23 Same-Unit
#                     (Satellite 22-22 temporal-after-e
#                       EDU:[once they get the ad...])
#                     (Nucleus 23-23 span EDU:[they buy it,"]))))
#               (Satellite 24-27 attribution
#                 (Nucleus 24-24 span EDU:[said Mr. Karatz,])
#                 (Satellite 25-27 elaboration-additional-e
#                   (Satellite 25-25 attribution EDU:[adding])
#                   (Nucleus 26-27 span
#                     (Satellite 26-26 attribution
#                       EDU:[that he believes])
#                     (Nucleus 27-27 span
#                       EDU:[the joint venture is...]))))))
#           (Satellite 28-28 elaboration-additional
#             EDU:["We usually operate ...]))
#         (Nucleus 29-33 span
#           (Nucleus 29-32 span
#             (Satellite 29-29 means EDU:[By setting up the jo...])
#             (Nucleus 30-32 span
#               (Nucleus 30-30 span EDU:[Kaufman & Broad can ...])
#               (Satellite 31-32 elaboration-object-attribute-e
#                 (Nucleus 31-31 Temporal-Same-Time
#                   EDU:[of buying raw land,])
#                 (Nucleus 32-32 Temporal-Same-Time
#                   EDU:[while avoiding the n...]))))
#           (Satellite 33-33 attribution EDU:[Mr. Karatz said.])))
#       (Satellite 34-35 explanation-argumentative
#         (Nucleus 34-34 span EDU:[The company is putti...])
#         (Satellite 35-35 antithesis EDU:[although it is respo...])))
#     (Satellite 36-39 elaboration-additional
#       (Nucleus 36-38 span
#         (Nucleus 36-36 span EDU:["This is one of the ...])
#         (Satellite 37-38 elaboration-object-attribute-e
#           (Nucleus 37-37 span EDU:[to assure a pipeline...])
#           (Satellite 38-38 purpose EDU:[to fuel our growth a...])))
#       (Satellite 39-39 attribution EDU:[Mr. Karatz said.]))))
